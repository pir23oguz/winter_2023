# %%
3+5
# Out:
# 8

# %%
print("Hello World")
# Out:
# Hello World

# %%
3+6
# Out:
# 9

# %%
hello world
# Out:
#   Cell In[4], line 1
#     hello world
#           ^
# SyntaxError: invalid syntax

# %%
print("hello world")
# Out:
# hello world

# %%
Print("hello world") # python is case sensetiv #buyuk kucuk harfe karsi duyarlidir.
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 Print("hello world") # python is case sensetiv #buyuk kucuk harfe karsi duyarlidir.
#
# NameError: name 'Print' is not defined

# %%
print("hello world')
# Out:
#   Cell In[8], line 1
#     print("hello world')
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print('hello world')
# Out:
# hello world

# %%
print('I'm a python teacher')
# Out:
#   Cell In[13], line 1
#     print('I'm a python teacher')
#                                ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
print("I'm a python teacher")
# Out:
# I'm a python teacher

# %%
# session_1

# %%
z
# Out:
# 1j

# %%
type(z)
# Out:
# complex

# %%
z = 1i
# Out:
#   Cell In[3], line 1
#     z = 1i
#         ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# # session_1

# %% [markdown]
# ### session_1

# %%
print("""python is awesome programing language""")
# Out:
# python is awesome programing language

# %%
print('''python is awesome programing language''')
# Out:
# python is awesome programing language

# %%
('''python is awesome programing language''')
# Out:
# 'python is awesome programing language'
